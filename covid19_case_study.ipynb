# %% [markdown]
# # Project - COVID-19 Analysis [EDA & Visualization]

# %% [markdown]
# ### Importing libraries & data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
# Out:
# <ipython-input-2-b68d41771c41>:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %% [markdown]
# ==========

# %% [markdown]
# ## EXPLORING SYRIA DATA

# %% [markdown]
# ### Listinf all countries / regions in our data

# %% [markdown]
# #### Let's first get 'Syria' data

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_syria.reset_index(drop = True , inplace = True)


df_syria
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         SYR      Asia    Syria  2020-01-03          NaN        0.0
# 1         SYR      Asia    Syria  2020-01-04          NaN        0.0
# 2         SYR      Asia    Syria  2020-01-05          NaN        0.0
# 3         SYR      Asia    Syria  2020-01-06          NaN        0.0
# 4         SYR      Asia    Syria  2020-01-07          NaN        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1423      SYR      Asia    Syria  2023-11-26      57423.0        0.0
# 1424      SYR      Asia    Syria  2023-11-27      57423.0        0.0
# 1425      SYR      Asia    Syria  2023-11-28      57423.0        0.0
# 1426      SYR      Asia    Syria  2023-11-29      57423.0        0.0
# 1427      SYR      Asia    Syria  2023-11-30      57423.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_syria.head()
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      SYR      Asia    Syria  2020-01-03          NaN        0.0
# 1      SYR      Asia    Syria  2020-01-04          NaN        0.0
# 2      SYR      Asia    Syria  2020-01-05          NaN        0.0
# 3      SYR      Asia    Syria  2020-01-06          NaN        0.0
# 4      SYR      Asia    Syria  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_syria.head(10).style.background_gradient(cmap='Reds')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
df_syria.tail()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1423      SYR      Asia    Syria  2023-11-26      57423.0        0.0
# 1424      SYR      Asia    Syria  2023-11-27      57423.0        0.0
# 1425      SYR      Asia    Syria  2023-11-28      57423.0        0.0
# 1426      SYR      Asia    Syria  2023-11-29      57423.0        0.0
# 1427      SYR      Asia    Syria  2023-11-30      57423.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1423                 0.0        3163.0         0.0                  0.0  ...
# 1424                 0.0        3163.0         0.0                  0.0  ...
# 1425                 0.0        3163.0         0.0                  0.0  ...
# 1426                 0.0        3163.0         0.0                  0.0  ...
# 1427                 0.0        3163.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_syria.head(10).style.background_gradient(cmap='Reds')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
df_syria.sample(6)
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 727      SYR      Asia    Syria  2021-12-30      50204.0       37.0
# 108      SYR      Asia    Syria  2020-04-20         39.0        1.0
# 370      SYR      Asia    Syria  2021-01-07      11988.0       98.0
# 961      SYR      Asia    Syria  2022-08-21      56838.0        7.0
# 161      SYR      Asia    Syria  2020-06-12        164.0       12.0
# 799      SYR      Asia    Syria  2022-03-12      55288.0       45.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 727              41.857        2889.0         5.0                4.286  ...
# 108               2.000           3.0         1.0                0.143  ...
# 370              92.000         747.0         6.0                6.143  ...
# 961              19.714        3160.0         0.0                0.429  ...
# 161               5.714           6.0         0.0                0.000  ...
# ...

# %%
df_syria.sample(6).style.background_gradient(cmap='Reds')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %% [markdown]
# ### Creating a summary table for the most recent 'Syria' data

# %%
df_syria[['total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
# Out:
#       total_cases  new_cases  total_deaths  new_deaths
# 0             NaN        0.0           NaN         0.0
# 1             NaN        0.0           NaN         0.0
# 2             NaN        0.0           NaN         0.0
# 3             NaN        0.0           NaN         0.0
# 4             NaN        0.0           NaN         0.0
# ...           ...        ...           ...         ...
# 1423      57423.0        0.0        3163.0         0.0
# 1424      57423.0        0.0        3163.0         0.0
# 1425      57423.0        0.0        3163.0         0.0
# 1426      57423.0        0.0        3163.0         0.0
# 1427      57423.0        0.0        3163.0         0.0
#
# [1428 rows x 4 columns]

# %%
df_syria_recent = df_syria[df_syria['date'] == df_syria.date.max()]
df_syria_recent
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1427      SYR      Asia    Syria  2023-11-30      57423.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1427                 0.0        3163.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1427           NaN                  70.598                         1.5
#
#       life_expectancy  human_development_index  population  \
# 1427             72.7                    0.567  22125242.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1427                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1427               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_syria_recent[['date','total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 1427  2023-11-30      57423.0        0.0        3163.0         0.0

# %% [markdown]
# ### Calculating the maximum values of 'Syria' data

# %%
df_syria[['total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]].max()
# Out:
# total_cases     57423.0
# new_cases         728.0
# total_deaths     3163.0
# new_deaths         21.0
# dtype: float64

# %% [markdown]
# ### The highest date recorded for death in Syria

# %%
df_syria[df_syria['total_cases'] == df_syria['total_cases'].max()]
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1078      SYR      Asia    Syria  2022-12-16      57423.0        1.0
# 1079      SYR      Asia    Syria  2022-12-17      57423.0        0.0
# 1080      SYR      Asia    Syria  2022-12-18      57423.0        0.0
# 1081      SYR      Asia    Syria  2022-12-19      57423.0        0.0
# 1082      SYR      Asia    Syria  2022-12-20      57423.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1423      SYR      Asia    Syria  2023-11-26      57423.0        0.0
# 1424      SYR      Asia    Syria  2023-11-27      57423.0        0.0
# 1425      SYR      Asia    Syria  2023-11-28      57423.0        0.0
# 1426      SYR      Asia    Syria  2023-11-29      57423.0        0.0
# 1427      SYR      Asia    Syria  2023-11-30      57423.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_syria[df_syria['new_deaths'] == df_syria['new_deaths'].max()]
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 655      SYR      Asia    Syria  2021-10-19      39488.0      402.0
# 657      SYR      Asia    Syria  2021-10-21      40630.0      728.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 655             322.714        2429.0        21.0               11.571  ...
# 657             405.143        2467.0        21.0               14.429  ...
#
#      male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 655           NaN                  70.598                         1.5
# 657           NaN                  70.598                         1.5
#
#      life_expectancy  human_development_index  population  \
# 655             72.7                    0.567  22125242.0
# 657             72.7                    0.567  22125242.0
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# ...

# %%
df_syria.loc[df_syria['new_deaths'].idxmax()]['date']
# Out:
# '2021-10-19'

# %%
df_syria[df_syria['new_deaths'] == df_syria['new_deaths'].max()]['date']
# Out:
# 655    2021-10-19
# 657    2021-10-21
# Name: date, dtype: object

# %% [markdown]
# ### The average value(s) of daily-recorded data in Syria

# %%
df_syria['new_deaths'].mean()
# Out:
# 2.2149859943977592

# %%
df_syria['new_deaths'].describe()
# Out:
# count    1428.000000
# mean        2.214986
# std         3.343561
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         4.000000
# max        21.000000
# Name: new_deaths, dtype: float64
